# %% [markdown]
# # tables_us_data.ipynb
#
# Build tables of the latest COVID-19 statistics for U.S. counties.
#
# Inputs:
# * `outputs/us_counties_clean.csv`: The contents of `data/us_counties.csv` after data cleaning by [clean_us_data.ipynb](./clean_us_data.ipynb)
# * `outputs/us_counties_clean_meta.json`: Column type metadata for reading `data/us_counties_clean.csv` with `pd.read_csv()`
#
# **Note:** You can redirect these input files by setting the environment variable `COVID_OUTPUTS_DIR` to a replacement for the prefix `outputs` in the above paths.

# %%
# Initialization boilerplate
import os
import json
import pandas as pd
import numpy as np
from typing import *

import text_extensions_for_pandas as tp

# Local file of utility functions
import util

# Allow environment variables to override data file locations.
_OUTPUTS_DIR = os.getenv("COVID_OUTPUTS_DIR", "outputs")
util.ensure_dir_exists(_OUTPUTS_DIR)  # create if necessary

# %% [markdown]
# # Read and Reformat Input Data

# %%
# Read in the CSV file and apply the saved type information
csv_file = os.path.join(_OUTPUTS_DIR, "us_counties_clean.csv")
meta_file = os.path.join(_OUTPUTS_DIR, "us_counties_clean_meta.json")

# Read column type metadata
with open(meta_file) as f:
    cases_meta = json.load(f)

# Pandas does not currently support parsing datetime64 from CSV files.
# As a workaround, read the "Date" column as objects and manually 
# convert after.
cases_meta["Date"] = "object"

cases_vertical = (
    pd
    .read_csv(csv_file, dtype=cases_meta, parse_dates=["Date"])   
    .set_index(["FIPS", "Date"], verify_integrity=True)
)
cases_vertical
# Out:
#                     State   County  Population  Confirmed  Deaths  Recovered  \
# FIPS  Date
# 1001  2020-01-22  Alabama  Autauga       55869          0       0          0
#       2020-01-23  Alabama  Autauga       55869          0       0          0
#       2020-01-24  Alabama  Autauga       55869          0       0          0
#       2020-01-25  Alabama  Autauga       55869          0       0          0
#       2020-01-26  Alabama  Autauga       55869          0       0          0
# ...                   ...      ...         ...        ...     ...        ...
# 56045 2020-09-12  Wyoming   Weston        6927         23       0          0
#       2020-09-13  Wyoming   Weston        6927         23       0          0
#       2020-09-14  Wyoming   Weston        6927         23       0          0
#       2020-09-15  Wyoming   Weston        6927         23       0          0
#       2020-09-16  Wyoming   Weston        6927         23       0          0
#
#                   Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier
# FIPS  Date
# 1001  2020-01-22              False           False              False
#       2020-01-23              False           False              False
#       2020-01-24              False           False              False
#       2020-01-25              False           False              False
#       2020-01-26              False           False              False
# ...                             ...             ...                ...
# 56045 2020-09-12              False           False              False
#       2020-09-13              False           False              False
#       2020-09-14              False           False              False
#       2020-09-15              False           False              False
#       2020-09-16              False           False              False
#
# [750938 rows x 9 columns]

# %% [markdown]
# ## Normalize the Confirmed and Deaths counts by population
#
# The populations of U.S. counties vary by several orders of magnitude, so it's useful to
# normalize the case count for each count to the county's population. Compute confirmed cases
# and deaths per 100 residents.

# %%
cases = cases_vertical.copy()
cases["Confirmed_per_100"] = cases["Confirmed"] / cases["Population"] * 100
cases["Deaths_per_100"] = cases["Deaths"] / cases["Population"] * 100
cases
# Out:
#                     State   County  Population  Confirmed  Deaths  Recovered  \
# FIPS  Date
# 1001  2020-01-22  Alabama  Autauga       55869          0       0          0
#       2020-01-23  Alabama  Autauga       55869          0       0          0
#       2020-01-24  Alabama  Autauga       55869          0       0          0
#       2020-01-25  Alabama  Autauga       55869          0       0          0
#       2020-01-26  Alabama  Autauga       55869          0       0          0
# ...                   ...      ...         ...        ...     ...        ...
# 56045 2020-09-12  Wyoming   Weston        6927         23       0          0
#       2020-09-13  Wyoming   Weston        6927         23       0          0
#       2020-09-14  Wyoming   Weston        6927         23       0          0
#       2020-09-15  Wyoming   Weston        6927         23       0          0
#       2020-09-16  Wyoming   Weston        6927         23       0          0
#
#                   Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier  \
# FIPS  Date
# 1001  2020-01-22              False           False              False
#       2020-01-23              False           False              False
#       2020-01-24              False           False              False
#       2020-01-25              False           False              False
#       2020-01-26              False           False              False
# ...                             ...             ...                ...
# 56045 2020-09-12              False           False              False
#       2020-09-13              False           False              False
#       2020-09-14              False           False              False
#       2020-09-15              False           False              False
#       2020-09-16              False           False              False
#
#                   Confirmed_per_100  Deaths_per_100
# FIPS  Date
# 1001  2020-01-22           0.000000             0.0
#       2020-01-23           0.000000             0.0
#       2020-01-24           0.000000             0.0
#       2020-01-25           0.000000             0.0
#       2020-01-26           0.000000             0.0
# ...                             ...             ...
# 56045 2020-09-12           0.332034             0.0
#       2020-09-13           0.332034             0.0
#       2020-09-14           0.332034             0.0
#       2020-09-15           0.332034             0.0
#       2020-09-16           0.332034             0.0
#
# [750938 rows x 11 columns]

# %% [markdown]
# ## Extract the most recent element of each time series
#
# Most of the tables below focus on the most recent day's data, so we generate a DataFrame with
# just the last element of each time series.

# %%
cases_without_index = cases.reset_index()
last_date = cases_without_index["Date"].max()
cases_by_county = (
    cases_without_index[cases_without_index["Date"] == last_date]
    .set_index("FIPS")
    .drop(columns=["Confirmed_Outlier", "Deaths_Outlier", "Recovered_Outlier"]))
cases_by_county
# Out:
#             Date    State      County  Population  Confirmed  Deaths  \
# FIPS
# 1001  2020-09-16  Alabama     Autauga       55869       1619      24
# 1003  2020-09-16  Alabama     Baldwin      223234       5003      47
# 1005  2020-09-16  Alabama     Barbour       24686        809       7
# 1007  2020-09-16  Alabama        Bibb       22394        612       9
# 1009  2020-09-16  Alabama      Blount       57826       1487      13
# ...          ...      ...         ...         ...        ...     ...
# 56037 2020-09-16  Wyoming  Sweetwater       42343        317       2
# 56039 2020-09-16  Wyoming       Teton       23464        481       1
# 56041 2020-09-16  Wyoming       Uinta       20226        323       2
# 56043 2020-09-16  Wyoming    Washakie        7805        111       6
# 56045 2020-09-16  Wyoming      Weston        6927         23       0
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 1001           0           2.897850        0.042958
# 1003           0           2.241146        0.021054
# 1005           0           3.277161        0.028356
# 1007           0           2.732875        0.040189
# 1009           0           2.571508        0.022481
# ...          ...                ...             ...
# 56037          0           0.748648        0.004723
# 56039          0           2.049949        0.004262
# 56041          0           1.596954        0.009888
# 56043          0           1.422165        0.076874
# 56045          0           0.332034        0.000000
#
# [3142 rows x 9 columns]

# %% [markdown]
# # Generate tables
#
# Now that we have read and formatted the input data, we can use Pandas to generate summary tables of the
# latest COVID-19 data.

# %% [markdown]
# ## Table: COVID-19 Cases and Deaths by State
#
# Aggregate the most recent county-level numbers by state to build up a table of statewide totals.

# %%
cases_by_state = (cases_by_county
 .groupby("State")
 .aggregate({
     "Population": "sum",
     "Confirmed": "sum",
     "Deaths": "sum"
 }))
cases_by_state["Confirmed_per_100"] = cases_by_state["Confirmed"] / cases_by_state["Population"] * 100
cases_by_state["Deaths_per_100"] = cases_by_state["Deaths"] / cases_by_state["Population"] * 100

cases_by_state = cases_by_state[["Population", "Confirmed", "Deaths", \
                                 "Confirmed_per_100", "Deaths_per_100"]]
cases_by_state
# Out:
#                       Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# Alabama                  4903185     141087    2392           2.877456
# Alaska                    731545       6431      44           0.879098
# Arizona                  7278717     209904    5370           2.883805
# Arkansas                 3017804      70761    1157           2.344784
# California              39512223     771321   14691           1.952107
# Colorado                 5758736      62666    2002           1.088190
# Connecticut              3565287      55034    4487           1.543606
# Delaware                  973764      18756     619           1.926134
# District of Columbia      705749      14743     617           2.088986
# Florida                 21477737     669635   12939           3.117810
# Georgia                 10617423     279937    6272           2.636581
# Hawaii                   1415872      10918     102           0.771115
# Idaho                    1787065      36089     429           2.019456
# Illinois                12671821     266093    8367           2.099880
# Indiana                  6732219     107809    3247           1.601389
# Iowa                     3155070      76630    1248           2.428789
# Kansas                   2913314      50720     578           1.740973
# Kentucky                 4467673      58764    1082           1.315316
# Louisiana                4648794     158634    5126           3.412369
# Maine                    1344212       4941     138           0.367576
# Maryland                 6045680     117888    3843           1.949954
# Massachusetts            6892503     123248    9239           1.788146
# Michigan                 9986857     119795    6865           1.199527
# Minnesota                5639632      85663    1933           1.518947
# Mississippi              2976149      91234    2756           3.065505
# Missouri                 6137428      97621    1665           1.590585
# Montana                  1068778       9431     141           0.882410
# Nebraska                 1934408      39249     439           2.028993
# Nevada                   3080156      74248    1494           2.410527
# New Hampshire            1359711       7780     438           0.572180
# New Jersey               8882190     197472   16054           2.223235
# New Mexico               2096829      25699     832           1.225613
# New York                19453561     446366   33025           2.294521
# North Carolina          10488084     188024    3149           1.792739
# North Dakota              762062      16333     177           2.143264
# Ohio                    11689100     140518    4555           1.202128
# Oklahoma                 3956971      72228     924           1.825336
# Oregon                   4217737      29850     521           0.707725
# Pennsylvania            12801989     151850    7882           1.186144
# Rhode Island             1059361      21374    1066           2.017631
# South Carolina           5148714     134122    3132           2.604961
# South Dakota              884659      17291     192           1.954538
# Tennessee                6829174     171625    2121           2.513115
# Texas                   28995881     696807   14738           2.403124
# Utah                     3205958      59749     436           1.863686
# Vermont                   623989       1694      58           0.271479
# Virginia                 8535519     136269    2882           1.596493
# Washington               7614893      80518    2016           1.057375
# West Virginia            1792147      13202     293           0.736658
# Wisconsin                5822434      92159    1227           1.582826
# Wyoming                   578759       4566      46           0.788929
#
#                       Deaths_per_100
# State
# Alabama                     0.048785
# Alaska                      0.006015
# Arizona                     0.073777
# Arkansas                    0.038339
# California                  0.037181
# Colorado                    0.034765
# Connecticut                 0.125852
# Delaware                    0.063568
# District of Columbia        0.087425
# Florida                     0.060244
# Georgia                     0.059073
# Hawaii                      0.007204
# Idaho                       0.024006
# Illinois                    0.066028
# Indiana                     0.048231
# Iowa                        0.039555
# Kansas                      0.019840
# Kentucky                    0.024218
# Louisiana                   0.110265
# Maine                       0.010266
# Maryland                    0.063566
# Massachusetts               0.134044
# Michigan                    0.068740
# Minnesota                   0.034275
# Mississippi                 0.092603
# Missouri                    0.027129
# Montana                     0.013193
# Nebraska                    0.022694
# Nevada                      0.048504
# New Hampshire               0.032213
# New Jersey                  0.180744
# New Mexico                  0.039679
# New York                    0.169763
# North Carolina              0.030025
# North Dakota                0.023226
# Ohio                        0.038968
# Oklahoma                    0.023351
# Oregon                      0.012353
# Pennsylvania                0.061569
# Rhode Island                0.100627
# South Carolina              0.060831
# South Dakota                0.021703
# Tennessee                   0.031058
# Texas                       0.050828
# Utah                        0.013600
# Vermont                     0.009295
# Virginia                    0.033765
# Washington                  0.026474
# West Virginia               0.016349
# Wisconsin                   0.021074
# Wyoming                     0.007948

# %%
# Now our data prep is done and we can start analyzing.

# The latest nationwide totals
cases_by_state[["Confirmed", "Deaths"]].sum()
# Out:
# Confirmed    6534746
# Deaths        195046
# dtype: int64

# %%
# Today's nationwide totals, computed from the county-level data
cases_by_county[["Confirmed", "Deaths"]].sum()
# Out:
# Confirmed    6534746
# Deaths        195046
# dtype: int64

# %% [markdown]
# ## Table: Top 10 states by total confirmed cases

# %%
cases_by_state.sort_values("Confirmed", ascending=False).head(10)
# Out:
#                 Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# California        39512223     771321   14691           1.952107
# Texas             28995881     696807   14738           2.403124
# Florida           21477737     669635   12939           3.117810
# New York          19453561     446366   33025           2.294521
# Georgia           10617423     279937    6272           2.636581
# Illinois          12671821     266093    8367           2.099880
# Arizona            7278717     209904    5370           2.883805
# New Jersey         8882190     197472   16054           2.223235
# North Carolina    10488084     188024    3149           1.792739
# Tennessee          6829174     171625    2121           2.513115
#
#                 Deaths_per_100
# State
# California            0.037181
# Texas                 0.050828
# Florida               0.060244
# New York              0.169763
# Georgia               0.059073
# Illinois              0.066028
# Arizona               0.073777
# New Jersey            0.180744
# North Carolina        0.030025
# Tennessee             0.031058

# %% [markdown]
# ## Table: Top 10 states by confirmed cases per 100 residents

# %%
cases_by_state.sort_values("Confirmed_per_100", ascending=False).head(10)
# Out:
#                 Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# Louisiana          4648794     158634    5126           3.412369
# Florida           21477737     669635   12939           3.117810
# Mississippi        2976149      91234    2756           3.065505
# Arizona            7278717     209904    5370           2.883805
# Alabama            4903185     141087    2392           2.877456
# Georgia           10617423     279937    6272           2.636581
# South Carolina     5148714     134122    3132           2.604961
# Tennessee          6829174     171625    2121           2.513115
# Iowa               3155070      76630    1248           2.428789
# Nevada             3080156      74248    1494           2.410527
#
#                 Deaths_per_100
# State
# Louisiana             0.110265
# Florida               0.060244
# Mississippi           0.092603
# Arizona               0.073777
# Alabama               0.048785
# Georgia               0.059073
# South Carolina        0.060831
# Tennessee             0.031058
# Iowa                  0.039555
# Nevada                0.048504

# %% [markdown]
# ## Table: Top 10 states by deaths per 100 residents

# %%
# Top 10 states by deaths per 100 residents
cases_by_state.sort_values("Deaths_per_100", ascending=False).head(10)
# Out:
#                       Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# New Jersey               8882190     197472   16054           2.223235
# New York                19453561     446366   33025           2.294521
# Massachusetts            6892503     123248    9239           1.788146
# Connecticut              3565287      55034    4487           1.543606
# Louisiana                4648794     158634    5126           3.412369
# Rhode Island             1059361      21374    1066           2.017631
# Mississippi              2976149      91234    2756           3.065505
# District of Columbia      705749      14743     617           2.088986
# Arizona                  7278717     209904    5370           2.883805
# Michigan                 9986857     119795    6865           1.199527
#
#                       Deaths_per_100
# State
# New Jersey                  0.180744
# New York                    0.169763
# Massachusetts               0.134044
# Connecticut                 0.125852
# Louisiana                   0.110265
# Rhode Island                0.100627
# Mississippi                 0.092603
# District of Columbia        0.087425
# Arizona                     0.073777
# Michigan                    0.068740

# %% [markdown]
# ## Table: Top 10 states by confirmed cases

# %%
cases_by_county.sort_values("Confirmed", ascending=False).head(20)
# Out:
#             Date       State          County  Population  Confirmed  Deaths  \
# FIPS
# 6037  2020-09-16  California     Los Angeles    10039107     256148    6303
# 12086 2020-09-16     Florida      Miami-Dade     2716940     165147    2955
# 4013  2020-09-16     Arizona        Maricopa     4485414     138151    3197
# 17031 2020-09-16    Illinois            Cook     5150233     136246    5146
# 48201 2020-09-16       Texas          Harris     4713325     120771    2458
# 48113 2020-09-16       Texas          Dallas     2635516      76149    1056
# 12011 2020-09-16     Florida         Broward     1952778      74832    1297
# 36081 2020-09-16    New York          Queens     2253858      71309    7235
# 36047 2020-09-16    New York           Kings     2559903      66468    7311
# 32003 2020-09-16      Nevada           Clark     2266715      63077    1298
# 6065  2020-09-16  California       Riverside     2470546      56201    1136
# 36005 2020-09-16    New York           Bronx     1418207      52371    4938
# 6059  2020-09-16  California          Orange     3175692      51259    1111
# 6071  2020-09-16  California  San Bernardino     2180085      51252     838
# 48029 2020-09-16       Texas           Bexar     2003554      50284    1228
# 36059 2020-09-16    New York          Nassau     1356924      45906    2199
# 36103 2020-09-16    New York         Suffolk     1476601      45843    2008
# 48439 2020-09-16       Texas         Tarrant     2102515      45583     673
# 12099 2020-09-16     Florida      Palm Beach     1496770      44459    1234
# 6073  2020-09-16  California       San Diego     3338330      43445     748
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 6037           0           2.551502        0.062784
# 12086          0           6.078419        0.108762
# 4013           0           3.080006        0.071275
# 17031          0           2.645434        0.099918
# 48201          0           2.562331        0.052150
# 48113          0           2.889339        0.040068
# 12011          0           3.832079        0.066418
# 36081          0           3.163864        0.321005
# 36047          0           2.596505        0.285597
# 32003          0           2.782749        0.057263
# 6065           0           2.274841        0.045982
# 36005          0           3.692761        0.348186
# 6059           0           1.614105        0.034985
# 6071           0           2.350918        0.038439
# 48029          0           2.509740        0.061291
# 36059          0           3.383093        0.162058
# 36103          0           3.104630        0.135988
# 48439          0           2.168023        0.032009
# 12099          0           2.970329        0.082444
# 6073           0           1.301399        0.022406

# %% [markdown]
# ## Table: Top 20 counties by confirmed cases per 100 residents

# %%
cases_by_county.sort_values("Confirmed_per_100", ascending=False).head(20)
# Out:
#             Date        State          County  Population  Confirmed  Deaths  \
# FIPS
# 13053 2020-09-16      Georgia   Chattahoochee       10907       1596       1
# 47169 2020-09-16    Tennessee       Trousdale       11284       1644       7
# 12067 2020-09-16      Florida       Lafayette        8422       1227      11
# 5079  2020-09-16     Arkansas         Lincoln       13024       1802      15
# 47095 2020-09-16    Tennessee            Lake        7016        864       2
# 5077  2020-09-16     Arkansas             Lee        8857       1041      16
# 31043 2020-09-16     Nebraska          Dakota       20026       2110      43
# 19021 2020-09-16         Iowa     Buena Vista       19620       1913      12
# 5017  2020-09-16     Arkansas          Chicot       10118        986      17
# 27105 2020-09-16    Minnesota          Nobles       21629       1912      16
# 22037 2020-09-16    Louisiana  East Feliciana       19135       1690      65
# 47181 2020-09-16    Tennessee           Wayne       16673       1471       5
# 22035 2020-09-16    Louisiana    East Carroll        6861        539       4
# 22065 2020-09-16    Louisiana         Madison       10951        857       8
# 28055 2020-09-16  Mississippi       Issaquena        1327        102       3
# 20057 2020-09-16       Kansas            Ford       33619       2546      10
# 20175 2020-09-16       Kansas          Seward       21428       1591       5
# 31037 2020-09-16     Nebraska          Colfax       10709        750       5
# 5133  2020-09-16     Arkansas          Sevier       17007       1186      16
# 40139 2020-09-16     Oklahoma           Texas       19983       1375       8
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 13053          0          14.632805        0.009168
# 47169          0          14.569302        0.062035
# 12067          0          14.568986        0.130610
# 5079           0          13.835995        0.115172
# 47095          0          12.314709        0.028506
# 5077           0          11.753415        0.180648
# 31043          0          10.536303        0.214721
# 19021          0           9.750255        0.061162
# 5017           0           9.745009        0.168017
# 27105          0           8.839983        0.073975
# 22037          0           8.831983        0.339692
# 47181          0           8.822647        0.029989
# 22035          0           7.855998        0.058301
# 22065          0           7.825769        0.073053
# 28055          0           7.686511        0.226074
# 20057          0           7.573099        0.029745
# 20175          0           7.424865        0.023334
# 31037          0           7.003455        0.046690
# 5133           0           6.973599        0.094079
# 40139          0           6.880849        0.040034

# %% [markdown]
# ## Table: Top 20 counties by deaths per 100 residents

# %%
cases_by_county.sort_values("Deaths_per_100", ascending=False).head(20)
# Out:
#             Date        State          County  Population  Confirmed  Deaths  \
# FIPS
# 13141 2020-09-16      Georgia         Hancock        8457        383      41
# 51640 2020-09-16     Virginia           Galax        6347        406      30
# 51595 2020-09-16     Virginia         Emporia        5346        244      23
# 13243 2020-09-16      Georgia        Randolph        6778        329      28
# 13273 2020-09-16      Georgia         Terrell        8531        325      31
# 28099 2020-09-16  Mississippi         Neshoba       29118       1513     103
# 35031 2020-09-16   New Mexico        McKinley       71367       4280     252
# 36005 2020-09-16     New York           Bronx     1418207      52371    4938
# 28051 2020-09-16  Mississippi          Holmes       17010       1076      58
# 22037 2020-09-16    Louisiana  East Feliciana       19135       1690      65
# 13165 2020-09-16      Georgia         Jenkins        8676        382      29
# 36081 2020-09-16     New York          Queens     2253858      71309    7235
# 13099 2020-09-16      Georgia           Early       10190        456      32
# 31135 2020-09-16     Nebraska         Perkins        2891         33       9
# 48047 2020-09-16        Texas          Brooks        7093        286      21
# 36047 2020-09-16     New York           Kings     2559903      66468    7311
# 28083 2020-09-16  Mississippi         Leflore       28183       1332      79
# 1085  2020-09-16      Alabama         Lowndes        9726        643      27
# 13287 2020-09-16      Georgia          Turner        7985        289      22
# 34013 2020-09-16   New Jersey           Essex      798975      20723    2124
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 13141          0           4.528793        0.484805
# 51640          0           6.396723        0.472664
# 51595          0           4.564160        0.430228
# 13243          0           4.853939        0.413101
# 13273          0           3.809635        0.363381
# 28099          0           5.196099        0.353733
# 35031          0           5.997170        0.353104
# 36005          0           3.692761        0.348186
# 28051          0           6.325691        0.340976
# 22037          0           8.831983        0.339692
# 13165          0           4.402951        0.334255
# 36081          0           3.163864        0.321005
# 13099          0           4.474975        0.314033
# 31135          0           1.141474        0.311311
# 48047          0           4.032144        0.296067
# 36047          0           2.596505        0.285597
# 28083          0           4.726253        0.280311
# 1085           0           6.611145        0.277606
# 13287          0           3.619286        0.275517
# 34013          0           2.593698        0.265841
