# %% [markdown]
# # tables_us_data.ipynb
#
# Build tables of the latest COVID-19 statistics for U.S. counties.
#
# Inputs:
# * `outputs/us_counties_clean.csv`: The contents of `data/us_counties.csv` after data cleaning by [clean_us_data.ipynb](./clean_us_data.ipynb)
# * `outputs/us_counties_clean_meta.json`: Column type metadata for reading `data/us_counties_clean.csv` with `pd.read_csv()`
#
# **Note:** You can redirect these input files by setting the environment variable `COVID_OUTPUTS_DIR` to a replacement for the prefix `outputs` in the above paths.

# %%
# Initialization boilerplate
import os
import json
import pandas as pd
import numpy as np
from typing import *

import text_extensions_for_pandas as tp

# Local file of utility functions
import util

# Allow environment variables to override data file locations.
_OUTPUTS_DIR = os.getenv("COVID_OUTPUTS_DIR", "outputs")
util.ensure_dir_exists(_OUTPUTS_DIR)  # create if necessary

# %%
# Read in the CSV file and apply the saved type information
csv_file = os.path.join(_OUTPUTS_DIR, "us_counties_clean.csv")
meta_file = os.path.join(_OUTPUTS_DIR, "us_counties_clean_meta.json")

# Read column type metadata
with open(meta_file) as f:
    cases_meta = json.load(f)

# Pandas does not currently support parsing datetime64 from CSV files.
# As a workaround, read the "Date" column as objects and manually 
# convert after.
cases_meta["Date"] = "object"

cases_vertical = (
    pd
    .read_csv(csv_file, dtype=cases_meta, parse_dates=["Date"])   
    .set_index(["FIPS", "Date"], verify_integrity=True)
)
cases_vertical
# Out:
#                     State   County  Population  Confirmed  Deaths  Recovered  \
# FIPS  Date
# 1001  2020-01-22  Alabama  Autauga       55869          0       0          0
#       2020-01-23  Alabama  Autauga       55869          0       0          0
#       2020-01-24  Alabama  Autauga       55869          0       0          0
#       2020-01-25  Alabama  Autauga       55869          0       0          0
#       2020-01-26  Alabama  Autauga       55869          0       0          0
# ...                   ...      ...         ...        ...     ...        ...
# 56045 2020-09-10  Wyoming   Weston        6927         21       0          0
#       2020-09-11  Wyoming   Weston        6927         21       0          0
#       2020-09-12  Wyoming   Weston        6927         23       0          0
#       2020-09-13  Wyoming   Weston        6927         23       0          0
#       2020-09-14  Wyoming   Weston        6927         23       0          0
#
#                   Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier
# FIPS  Date
# 1001  2020-01-22              False           False              False
#       2020-01-23              False           False              False
#       2020-01-24              False           False              False
#       2020-01-25              False           False              False
#       2020-01-26              False           False              False
# ...                             ...             ...                ...
# 56045 2020-09-10              False           False              False
#       2020-09-11              False           False              False
#       2020-09-12              False           False              False
#       2020-09-13              False           False              False
#       2020-09-14              False           False              False
#
# [744654 rows x 9 columns]

# %%
# Normalize the Confirmed and Deaths counts by population.
cases = cases_vertical.copy()
cases["Confirmed_per_100"] = cases["Confirmed"] / cases["Population"] * 100
cases["Deaths_per_100"] = cases["Deaths"] / cases["Population"] * 100
cases
# Out:
#                     State   County  Population  Confirmed  Deaths  Recovered  \
# FIPS  Date
# 1001  2020-01-22  Alabama  Autauga       55869          0       0          0
#       2020-01-23  Alabama  Autauga       55869          0       0          0
#       2020-01-24  Alabama  Autauga       55869          0       0          0
#       2020-01-25  Alabama  Autauga       55869          0       0          0
#       2020-01-26  Alabama  Autauga       55869          0       0          0
# ...                   ...      ...         ...        ...     ...        ...
# 56045 2020-09-10  Wyoming   Weston        6927         21       0          0
#       2020-09-11  Wyoming   Weston        6927         21       0          0
#       2020-09-12  Wyoming   Weston        6927         23       0          0
#       2020-09-13  Wyoming   Weston        6927         23       0          0
#       2020-09-14  Wyoming   Weston        6927         23       0          0
#
#                   Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier  \
# FIPS  Date
# 1001  2020-01-22              False           False              False
#       2020-01-23              False           False              False
#       2020-01-24              False           False              False
#       2020-01-25              False           False              False
#       2020-01-26              False           False              False
# ...                             ...             ...                ...
# 56045 2020-09-10              False           False              False
#       2020-09-11              False           False              False
#       2020-09-12              False           False              False
#       2020-09-13              False           False              False
#       2020-09-14              False           False              False
#
#                   Confirmed_per_100  Deaths_per_100
# FIPS  Date
# 1001  2020-01-22           0.000000             0.0
#       2020-01-23           0.000000             0.0
#       2020-01-24           0.000000             0.0
#       2020-01-25           0.000000             0.0
#       2020-01-26           0.000000             0.0
# ...                             ...             ...
# 56045 2020-09-10           0.303162             0.0
#       2020-09-11           0.303162             0.0
#       2020-09-12           0.332034             0.0
#       2020-09-13           0.332034             0.0
#       2020-09-14           0.332034             0.0
#
# [744654 rows x 11 columns]

# %%
# Pull off the most recent element of each time series.
cases_without_index = cases.reset_index()
last_date = cases_without_index["Date"].max()
cases_by_county = (
    cases_without_index[cases_without_index["Date"] == last_date]
    .set_index("FIPS")
    .drop(columns=["Confirmed_Outlier", "Deaths_Outlier", "Recovered_Outlier"]))
cases_by_county
# Out:
#             Date    State      County  Population  Confirmed  Deaths  \
# FIPS
# 1001  2020-09-14  Alabama     Autauga       55869       1447      23
# 1003  2020-09-14  Alabama     Baldwin      223234       4800      43
# 1005  2020-09-14  Alabama     Barbour       24686        626       7
# 1007  2020-09-14  Alabama        Bibb       22394        581       6
# 1009  2020-09-14  Alabama      Blount       57826       1128      13
# ...          ...      ...         ...         ...        ...     ...
# 56037 2020-09-14  Wyoming  Sweetwater       42343        317       2
# 56039 2020-09-14  Wyoming       Teton       23464        476       1
# 56041 2020-09-14  Wyoming       Uinta       20226        312       2
# 56043 2020-09-14  Wyoming    Washakie        7805        111       6
# 56045 2020-09-14  Wyoming      Weston        6927         23       0
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 1001           0           2.589987        0.041168
# 1003           0           2.150210        0.019262
# 1005           0           2.535850        0.028356
# 1007           0           2.594445        0.026793
# 1009           0           1.950680        0.022481
# ...          ...                ...             ...
# 56037          0           0.748648        0.004723
# 56039          0           2.028640        0.004262
# 56041          0           1.542569        0.009888
# 56043          0           1.422165        0.076874
# 56045          0           0.332034        0.000000
#
# [3142 rows x 9 columns]

# %%
# Build a second table of the same data aggregated at the state level
cases_by_state = (cases_by_county
 .groupby("State")
 .aggregate({
     "Population": "sum",
     "Confirmed": "sum",
     "Deaths": "sum"
 }))
cases_by_state["Confirmed_per_100"] = cases_by_state["Confirmed"] / cases_by_state["Population"] * 100
cases_by_state["Deaths_per_100"] = cases_by_state["Deaths"] / cases_by_state["Population"] * 100

cases_by_state = cases_by_state[["Population", "Confirmed", "Deaths", \
                                 "Confirmed_per_100", "Deaths_per_100"]]
cases_by_state
# Out:
#                       Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# Alabama                  4903185     126299    2221           2.575856
# Alaska                    731545       6341      44           0.866796
# Arizona                  7278717     208725    5321           2.867607
# Arkansas                 3017804      68999     992           2.286398
# California              39512223     765134   14439           1.936449
# Colorado                 5758736      61667    1990           1.070843
# Connecticut              3565287      54769    4485           1.536174
# Delaware                  973764      18467     617           1.896455
# District of Columbia      705749      14622     616           2.071841
# Florida                 21477737     664692   12642           3.094795
# Georgia                 10617423     276285    6208           2.602185
# Hawaii                   1415872      10753      98           0.759461
# Idaho                    1787065      35531     419           1.988232
# Illinois                12671821     262692    8314           2.073041
# Indiana                  6732219     106540    3215           1.582539
# Iowa                     3155070      75051    1224           2.378743
# Kansas                   2913314      49660     542           1.704588
# Kentucky                 4467673      57282    1065           1.282144
# Louisiana                4648794     157751    5082           3.393375
# Maine                    1344212       4903     136           0.364749
# Maryland                 6045680     116646    3831           1.929411
# Massachusetts            6892503     122667    9213           1.779716
# Michigan                 9986857     118322    6843           1.184777
# Minnesota                5639632      84793    1922           1.503520
# Mississippi              2976149      90018    2706           3.024647
# Missouri                 6137428      95059    1641           1.548841
# Montana                  1068778       9107     138           0.852095
# Nebraska                 1934408      38482     435           1.989342
# Nevada                   3080156      73814    1456           2.396437
# New Hampshire            1359711       7711     436           0.567106
# New Jersey               8882190     196655   16034           2.214037
# New Mexico               2096829      25505     823           1.216361
# New York                19453561     455859   38230           2.343319
# North Carolina          10488084     185780    3060           1.771344
# North Dakota              762062      15831     170           2.077390
# Ohio                    11689100     138484    4419           1.184728
# Oklahoma                 3956971      70176     905           1.773478
# Oregon                   4217737      29337     509           0.695563
# Pennsylvania            12801989     150000    7855           1.171693
# Rhode Island             1059361      20824    1049           1.965713
# South Carolina           5148714     132680    3077           2.576954
# South Dakota              884659      16801     184           1.899150
# Tennessee                6829174     168800    2066           2.471748
# Texas                   28995881     685748   14451           2.364984
# Utah                     3205958      58433     435           1.822638
# Vermont                   623989       1688      58           0.270518
# Virginia                 8535519     134493    2743           1.575686
# Washington               7614893      79850    2002           1.048603
# West Virginia            1792147      12830     278           0.715901
# Wisconsin                5822434      89956    1210           1.544990
# Wyoming                   578759       4392      42           0.758865
#
#                       Deaths_per_100
# State
# Alabama                     0.045297
# Alaska                      0.006015
# Arizona                     0.073104
# Arkansas                    0.032872
# California                  0.036543
# Colorado                    0.034556
# Connecticut                 0.125796
# Delaware                    0.063362
# District of Columbia        0.087283
# Florida                     0.058861
# Georgia                     0.058470
# Hawaii                      0.006922
# Idaho                       0.023446
# Illinois                    0.065610
# Indiana                     0.047755
# Iowa                        0.038795
# Kansas                      0.018604
# Kentucky                    0.023838
# Louisiana                   0.109319
# Maine                       0.010117
# Maryland                    0.063368
# Massachusetts               0.133667
# Michigan                    0.068520
# Minnesota                   0.034080
# Mississippi                 0.090923
# Missouri                    0.026738
# Montana                     0.012912
# Nebraska                    0.022488
# Nevada                      0.047270
# New Hampshire               0.032066
# New Jersey                  0.180519
# New Mexico                  0.039250
# New York                    0.196519
# North Carolina              0.029176
# North Dakota                0.022308
# Ohio                        0.037804
# Oklahoma                    0.022871
# Oregon                      0.012068
# Pennsylvania                0.061358
# Rhode Island                0.099022
# South Carolina              0.059762
# South Dakota                0.020799
# Tennessee                   0.030253
# Texas                       0.049838
# Utah                        0.013568
# Vermont                     0.009295
# Virginia                    0.032136
# Washington                  0.026291
# West Virginia               0.015512
# Wisconsin                   0.020782
# Wyoming                     0.007257

# %%
# Now our data prep is done and we can start analyzing.

# The latest nationwide totals
cases_by_state[["Confirmed", "Deaths"]].sum()
# Out:
# Confirmed    6456904
# Deaths        197891
# dtype: int64

# %%
# Today's nationwide totals, computed from the county-level data
cases_by_county[["Confirmed", "Deaths"]].sum()
# Out:
# Confirmed    6456904
# Deaths        197891
# dtype: int64

# %%
# Top 10 states by confirmed cases:
cases_by_state.sort_values("Confirmed", ascending=False).head(10)
# Out:
#                 Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# California        39512223     765134   14439           1.936449
# Texas             28995881     685748   14451           2.364984
# Florida           21477737     664692   12642           3.094795
# New York          19453561     455859   38230           2.343319
# Georgia           10617423     276285    6208           2.602185
# Illinois          12671821     262692    8314           2.073041
# Arizona            7278717     208725    5321           2.867607
# New Jersey         8882190     196655   16034           2.214037
# North Carolina    10488084     185780    3060           1.771344
# Tennessee          6829174     168800    2066           2.471748
#
#                 Deaths_per_100
# State
# California            0.036543
# Texas                 0.049838
# Florida               0.058861
# New York              0.196519
# Georgia               0.058470
# Illinois              0.065610
# Arizona               0.073104
# New Jersey            0.180519
# North Carolina        0.029176
# Tennessee             0.030253

# %%
# Top 10 states by confirmed cases per 100 residents
cases_by_state.sort_values("Confirmed_per_100", ascending=False).head(10)
# Out:
#                 Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# Louisiana          4648794     157751    5082           3.393375
# Florida           21477737     664692   12642           3.094795
# Mississippi        2976149      90018    2706           3.024647
# Arizona            7278717     208725    5321           2.867607
# Georgia           10617423     276285    6208           2.602185
# South Carolina     5148714     132680    3077           2.576954
# Alabama            4903185     126299    2221           2.575856
# Tennessee          6829174     168800    2066           2.471748
# Nevada             3080156      73814    1456           2.396437
# Iowa               3155070      75051    1224           2.378743
#
#                 Deaths_per_100
# State
# Louisiana             0.109319
# Florida               0.058861
# Mississippi           0.090923
# Arizona               0.073104
# Georgia               0.058470
# South Carolina        0.059762
# Alabama               0.045297
# Tennessee             0.030253
# Nevada                0.047270
# Iowa                  0.038795

# %%
# Top 10 states by deaths per 100 residents
cases_by_state.sort_values("Deaths_per_100", ascending=False).head(10)
# Out:
#                       Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# New York                19453561     455859   38230           2.343319
# New Jersey               8882190     196655   16034           2.214037
# Massachusetts            6892503     122667    9213           1.779716
# Connecticut              3565287      54769    4485           1.536174
# Louisiana                4648794     157751    5082           3.393375
# Rhode Island             1059361      20824    1049           1.965713
# Mississippi              2976149      90018    2706           3.024647
# District of Columbia      705749      14622     616           2.071841
# Arizona                  7278717     208725    5321           2.867607
# Michigan                 9986857     118322    6843           1.184777
#
#                       Deaths_per_100
# State
# New York                    0.196519
# New Jersey                  0.180519
# Massachusetts               0.133667
# Connecticut                 0.125796
# Louisiana                   0.109319
# Rhode Island                0.099022
# Mississippi                 0.090923
# District of Columbia        0.087283
# Arizona                     0.073104
# Michigan                    0.068520

# %%
# Top 20 counties by total confirmed cases.
cases_by_county.sort_values("Confirmed", ascending=False).head(20)
# Out:
#             Date       State          County  Population  Confirmed  Deaths  \
# FIPS
# 6037  2020-09-14  California     Los Angeles    10039107     254656    6231
# 12086 2020-09-14     Florida      Miami-Dade     2716940     164299    2894
# 4013  2020-09-14     Arizona        Maricopa     4485414     137589    3154
# 17031 2020-09-14    Illinois            Cook     5150233     135274    5134
# 48201 2020-09-14       Texas          Harris     4713325     117568    2423
# 36081 2020-09-14    New York          Queens     2253858      76673    8521
# 48113 2020-09-14       Texas          Dallas     2635516      75648    1046
# 12011 2020-09-14     Florida         Broward     1952778      74525    1284
# 36047 2020-09-14    New York           Kings     2559903      67965    9157
# 32003 2020-09-14      Nevada           Clark     2266715      62812    1262
# 36005 2020-09-14    New York           Bronx     1418207      56593    6074
# 6065  2020-09-14  California       Riverside     2470546      55766    1118
# 6059  2020-09-14  California          Orange     3175692      50974    1093
# 6071  2020-09-14  California  San Bernardino     2180085      50709     832
# 48029 2020-09-14       Texas           Bexar     2003554      50016    1205
# 36059 2020-09-14    New York          Nassau     1356924      45763    2199
# 36103 2020-09-14    New York         Suffolk     1476601      45714    2008
# 48439 2020-09-14       Texas         Tarrant     2102515      44727     662
# 12099 2020-09-14     Florida      Palm Beach     1496770      44139    1199
# 6073  2020-09-14  California       San Diego     3338330      42887     734
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 6037           0           2.536640        0.062067
# 12086          0           6.047208        0.106517
# 4013           0           3.067476        0.070317
# 17031          0           2.626561        0.099685
# 48201          0           2.494375        0.051407
# 36081          0           3.401856        0.378063
# 48113          0           2.870330        0.039689
# 12011          0           3.816358        0.065752
# 36047          0           2.654983        0.357709
# 32003          0           2.771059        0.055675
# 36005          0           3.990461        0.428287
# 6065           0           2.257234        0.045253
# 6059           0           1.605130        0.034418
# 6071           0           2.326010        0.038164
# 48029          0           2.496364        0.060143
# 36059          0           3.372554        0.162058
# 36103          0           3.095894        0.135988
# 48439          0           2.127309        0.031486
# 12099          0           2.948950        0.080106
# 6073           0           1.284684        0.021987

# %%
# Top 20 counties by confirmed cases per 100 residents
cases_by_county.sort_values("Confirmed_per_100", ascending=False).head(20)
# Out:
#             Date        State          County  Population  Confirmed  Deaths  \
# FIPS
# 47169 2020-09-14    Tennessee       Trousdale       11284       1641       7
# 13053 2020-09-14      Georgia   Chattahoochee       10907       1584       2
# 12067 2020-09-14      Florida       Lafayette        8422       1220      10
# 5079  2020-09-14     Arkansas         Lincoln       13024       1785      13
# 47095 2020-09-14    Tennessee            Lake        7016        863       2
# 5077  2020-09-14     Arkansas             Lee        8857       1024      15
# 31043 2020-09-14     Nebraska          Dakota       20026       2085      43
# 19021 2020-09-14         Iowa     Buena Vista       19620       1901      12
# 5017  2020-09-14     Arkansas          Chicot       10118        976      16
# 47181 2020-09-14    Tennessee           Wayne       16673       1477       4
# 27105 2020-09-14    Minnesota          Nobles       21629       1906      15
# 22037 2020-09-14    Louisiana  East Feliciana       19135       1675      60
# 22035 2020-09-14    Louisiana    East Carroll        6861        538       4
# 22065 2020-09-14    Louisiana         Madison       10951        854       8
# 20057 2020-09-14       Kansas            Ford       33619       2514      10
# 28055 2020-09-14  Mississippi       Issaquena        1327         99       3
# 20175 2020-09-14       Kansas          Seward       21428       1518       5
# 5133  2020-09-14     Arkansas          Sevier       17007       1183      16
# 31037 2020-09-14     Nebraska          Colfax       10709        744       5
# 40139 2020-09-14     Oklahoma           Texas       19983       1321       8
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 47169          0          14.542715        0.062035
# 13053          0          14.522784        0.018337
# 12067          0          14.485870        0.118737
# 5079           0          13.705467        0.099816
# 47095          0          12.300456        0.028506
# 5077           0          11.561477        0.169358
# 31043          0          10.411465        0.214721
# 19021          0           9.689093        0.061162
# 5017           0           9.646175        0.158134
# 47181          0           8.858634        0.023991
# 27105          0           8.812243        0.069351
# 22037          0           8.753593        0.313562
# 22035          0           7.841423        0.058301
# 22065          0           7.798375        0.073053
# 20057          0           7.477914        0.029745
# 28055          0           7.460437        0.226074
# 20175          0           7.084189        0.023334
# 5133           0           6.955959        0.094079
# 31037          0           6.947427        0.046690
# 40139          0           6.610619        0.040034

# %%
# Top 20 counties by *deaths* per 100 residents
cases_by_county.sort_values("Deaths_per_100", ascending=False).head(20)
# Out:
#             Date        State          County  Population  Confirmed  Deaths  \
# FIPS
# 13141 2020-09-14      Georgia         Hancock        8457        379      41
# 51640 2020-09-14     Virginia           Galax        6347        406      28
# 36005 2020-09-14     New York           Bronx     1418207      56593    6074
# 13243 2020-09-14      Georgia        Randolph        6778        327      27
# 36081 2020-09-14     New York          Queens     2253858      76673    8521
# 13273 2020-09-14      Georgia         Terrell        8531        325      31
# 36047 2020-09-14     New York           Kings     2559903      67965    9157
# 51595 2020-09-14     Virginia         Emporia        5346        243      19
# 35031 2020-09-14   New Mexico        McKinley       71367       4266     251
# 28099 2020-09-14  Mississippi         Neshoba       29118       1497     102
# 28051 2020-09-14  Mississippi          Holmes       17010       1075      57
# 13165 2020-09-14      Georgia         Jenkins        8676        375      29
# 13099 2020-09-14      Georgia           Early       10190        447      32
# 22037 2020-09-14    Louisiana  East Feliciana       19135       1675      60
# 31135 2020-09-14     Nebraska         Perkins        2891         32       9
# 48047 2020-09-14        Texas          Brooks        7093        282      20
# 28083 2020-09-14  Mississippi         Leflore       28183       1322      79
# 13287 2020-09-14      Georgia          Turner        7985        287      22
# 36085 2020-09-14     New York        Richmond      476143      16875    1289
# 34013 2020-09-14   New Jersey           Essex      798975      20669    2123
#
#        Recovered  Confirmed_per_100  Deaths_per_100
# FIPS
# 13141          0           4.481495        0.484805
# 51640          0           6.396723        0.441153
# 36005          0           3.990461        0.428287
# 13243          0           4.824432        0.398348
# 36081          0           3.401856        0.378063
# 13273          0           3.809635        0.363381
# 36047          0           2.654983        0.357709
# 51595          0           4.545455        0.355406
# 35031          0           5.977553        0.351703
# 28099          0           5.141150        0.350299
# 28051          0           6.319812        0.335097
# 13165          0           4.322268        0.334255
# 13099          0           4.386654        0.314033
# 22037          0           8.753593        0.313562
# 31135          0           1.106883        0.311311
# 48047          0           3.975751        0.281968
# 28083          0           4.690771        0.280311
# 13287          0           3.594239        0.275517
# 36085          0           3.544103        0.270717
# 34013          0           2.586940        0.265715
