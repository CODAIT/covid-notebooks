# %%
# !pip install pandas==1.0.3 regex matplotlib==3.2.1 cython grpcio-tools scikit-learn pyarrow fastparquet plotly memoized-property opt-einsum==2.3.2 > /dev/null 2>&1

# %%
# !pip install --upgrade git+https://github.com/frreiss/text-extensions-for-pandas > /dev/null 2>&1

# %%
# %load util.py

# %% [markdown]
# # tables_us_data.ipynb
#
# Build tables of the latest COVID-19 statistics for U.S. counties.
#
# Inputs:
# * `data/us_counties_clean.csv`: The contents of `data/us_counties.csv` after data cleaning by `clean.ipynb`
# * `data/us_counties_clean_meta.json`: Column type metadata for reading `data/us_counties_clean.csv` with `pd.read_csv()`

# %%
# Initialization boilerplate

# Ensure a consistent Python environment.
#import sys
#sys.path.append("..")  # Local libraries are in the directory above "notebooks"
#import env
#env.maybe_install_libs()

import os
import json
import pandas as pd
import numpy as np

from typing import *

import text_extensions_for_pandas as tp

# Local file of utility functions
import util

_DATA_DIR = os.getenv('COVID_DATA_DIR', '../data')

# %%
# Read in the CSV file and apply the saved type information
csv_file = os.path.join(_DATA_DIR, "us_counties_clean.csv")
meta_file = os.path.join(_DATA_DIR, "us_counties_clean_meta.json")

# Read column type metadata
with open(meta_file) as f:
    cases_meta = json.load(f)

# Pandas does not currently support parsing datetime64 from CSV files.
# As a workaround, read the "Date" column as objects and manually 
# convert after.
cases_meta["Date"] = "object"

cases_vertical = (
    pd
    .read_csv(csv_file, dtype=cases_meta, parse_dates=["Date"])   
    .set_index(["FIPS", "Date"], verify_integrity=True)
)
cases_vertical
# Out:
#                     State   County  Population  Confirmed  Deaths  Recovered  \
# FIPS  Date
# 1001  2020-01-22  Alabama  Autauga       55869          0       0          0
#       2020-01-23  Alabama  Autauga       55869          0       0          0
#       2020-01-24  Alabama  Autauga       55869          0       0          0
#       2020-01-25  Alabama  Autauga       55869          0       0          0
#       2020-01-26  Alabama  Autauga       55869          0       0          0
# ...                   ...      ...         ...        ...     ...        ...
# 56045 2020-04-23  Wyoming   Weston        6927          0       0          0
#       2020-04-24  Wyoming   Weston        6927          0       0          0
#       2020-04-25  Wyoming   Weston        6927          0       0          0
#       2020-04-26  Wyoming   Weston        6927          0       0          0
#       2020-04-27  Wyoming   Weston        6927          0       0          0
#
#                   Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier
# FIPS  Date
# 1001  2020-01-22              False           False              False
#       2020-01-23              False           False              False
#       2020-01-24              False           False              False
#       2020-01-25              False           False              False
#       2020-01-26              False           False              False
# ...                             ...             ...                ...
# 56045 2020-04-23              False           False              False
#       2020-04-24              False           False              False
#       2020-04-25              False           False              False
#       2020-04-26              False           False              False
#       2020-04-27              False           False              False
#
# [304774 rows x 9 columns]

# %%
# Normalize the Confirmed and Deaths counts by population.
cases = cases_vertical.copy()
cases["Confirmed_per_100"] = cases["Confirmed"] / cases["Population"] * 100
cases["Deaths_per_100"] = cases["Deaths"] / cases["Population"] * 100
cases
# Out:
#                     State   County  Population  Confirmed  Deaths  Recovered  \
# FIPS  Date
# 1001  2020-01-22  Alabama  Autauga       55869          0       0          0
#       2020-01-23  Alabama  Autauga       55869          0       0          0
#       2020-01-24  Alabama  Autauga       55869          0       0          0
#       2020-01-25  Alabama  Autauga       55869          0       0          0
#       2020-01-26  Alabama  Autauga       55869          0       0          0
# ...                   ...      ...         ...        ...     ...        ...
# 56045 2020-04-23  Wyoming   Weston        6927          0       0          0
#       2020-04-24  Wyoming   Weston        6927          0       0          0
#       2020-04-25  Wyoming   Weston        6927          0       0          0
#       2020-04-26  Wyoming   Weston        6927          0       0          0
#       2020-04-27  Wyoming   Weston        6927          0       0          0
#
#                   Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier  \
# FIPS  Date
# 1001  2020-01-22              False           False              False
#       2020-01-23              False           False              False
#       2020-01-24              False           False              False
#       2020-01-25              False           False              False
#       2020-01-26              False           False              False
# ...                             ...             ...                ...
# 56045 2020-04-23              False           False              False
#       2020-04-24              False           False              False
#       2020-04-25              False           False              False
#       2020-04-26              False           False              False
#       2020-04-27              False           False              False
#
#                   Confirmed_per_100  Deaths_per_100
# FIPS  Date
# 1001  2020-01-22                0.0             0.0
#       2020-01-23                0.0             0.0
#       2020-01-24                0.0             0.0
#       2020-01-25                0.0             0.0
#       2020-01-26                0.0             0.0
# ...                             ...             ...
# 56045 2020-04-23                0.0             0.0
#       2020-04-24                0.0             0.0
#       2020-04-25                0.0             0.0
#       2020-04-26                0.0             0.0
#       2020-04-27                0.0             0.0
#
# [304774 rows x 11 columns]

# %%
# Pull off the most recent element of each time series.
cases_without_index = cases.reset_index()
last_date = cases_without_index["Date"].max()
cases_by_county = cases_without_index[cases_without_index["Date"] == last_date].set_index("FIPS")
cases_by_county
# Out:
#             Date    State      County  Population  Confirmed  Deaths  \
# FIPS
# 1001  2020-04-27  Alabama     Autauga       55869         39       3
# 1003  2020-04-27  Alabama     Baldwin      223234        168       3
# 1005  2020-04-27  Alabama     Barbour       24686         35       0
# 1007  2020-04-27  Alabama        Bibb       22394         42       0
# 1009  2020-04-27  Alabama      Blount       57826         34       0
# ...          ...      ...         ...         ...        ...     ...
# 56037 2020-04-27  Wyoming  Sweetwater       42343         16       0
# 56039 2020-04-27  Wyoming       Teton       23464         95       0
# 56041 2020-04-27  Wyoming       Uinta       20226          7       0
# 56043 2020-04-27  Wyoming    Washakie        7805          8       0
# 56045 2020-04-27  Wyoming      Weston        6927          0       0
#
#        Recovered  Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier  \
# FIPS
# 1001           0              False           False              False
# 1003           0              False           False              False
# 1005           0              False           False              False
# 1007           0              False           False              False
# 1009           0              False           False              False
# ...          ...                ...             ...                ...
# 56037          0              False           False              False
# 56039          0              False           False              False
# 56041          0              False           False              False
# 56043          0              False           False              False
# 56045          0              False           False              False
#
#        Confirmed_per_100  Deaths_per_100
# FIPS
# 1001            0.069806        0.005370
# 1003            0.075257        0.001344
# 1005            0.141781        0.000000
# 1007            0.187550        0.000000
# 1009            0.058797        0.000000
# ...                  ...             ...
# 56037           0.037787        0.000000
# 56039           0.404876        0.000000
# 56041           0.034609        0.000000
# 56043           0.102498        0.000000
# 56045           0.000000        0.000000
#
# [3142 rows x 12 columns]

# %%
# Build a second table of the same data aggregated at the state level
cases_by_state = (cases_by_county
 .groupby("State")
 .aggregate({
     "Population": "sum",
     "Confirmed": "sum",
     "Deaths": "sum"
 }))
cases_by_state["Confirmed_per_100"] = cases_by_state["Confirmed"] / cases_by_state["Population"] * 100
cases_by_state["Deaths_per_100"] = cases_by_state["Deaths"] / cases_by_state["Population"] * 100

cases_by_state = cases_by_state[["Population", "Confirmed", "Deaths", \
                                 "Confirmed_per_100", "Deaths_per_100"]]
cases_by_state
# Out:
#                       Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# Alabama                  4903185       6539     228           0.133362
# Alaska                    731545        345       5           0.047160
# Arizona                  7278717       6725     275           0.092393
# Arkansas                 3017804       2866      51           0.094970
# California              39512223      44966    1777           0.113803
# Colorado                 5758736      13703     702           0.237952
# Connecticut              3565287      25513    2011           0.715595
# Delaware                  973764       4151     125           0.426284
# District of Columbia      705749       3892     185           0.551471
# Florida                 21477737      32137    1088           0.149629
# Georgia                 10617423      22642     980           0.213253
# Hawaii                   1415872        600      16           0.042377
# Idaho                    1787065       1897      56           0.106152
# Illinois                12671821      45545    1983           0.359420
# Indiana                  6732219      15961     844           0.237084
# Iowa                     3155070       5861     127           0.185764
# Kansas                   2913314       3473     126           0.119211
# Kentucky                 4467673       4098     213           0.091726
# Louisiana                4648794      27004    1697           0.580882
# Maine                    1344212       1021      51           0.075955
# Maryland                 6045680      19487     858           0.322329
# Massachusetts            6892503      55642    2994           0.807283
# Michigan                 9986857      37056    3367           0.371048
# Minnesota                5639632       3811     286           0.067575
# Mississippi              2976149       6094     229           0.204761
# Missouri                 6137428       6804     328           0.110861
# Montana                  1068778        449      14           0.042011
# Nebraska                 1934408       3324      38           0.171836
# Nevada                   3080156       4700     205           0.152590
# New Hampshire            1359711       1927       3           0.141721
# New Jersey               8882190     110370    6044           1.242599
# New Mexico               2096829       2825      99           0.134727
# New York                19453561     291994   22666           1.500980
# North Carolina          10488084       9427     340           0.089883
# North Dakota              762062        942      19           0.123612
# Ohio                    11689100      16325     753           0.139660
# Oklahoma                 3956971       3281     197           0.082917
# Oregon                   4217737       2354      92           0.055812
# Pennsylvania            12801989      43558    1886           0.340244
# Rhode Island             1059361       6548       0           0.618108
# South Carolina           5148714       5613     177           0.109018
# South Dakota              884659       2244      11           0.253657
# Tennessee                6829174       9586     181           0.140368
# Texas                   28995881      25321     666           0.087326
# Utah                     3205958       3893      36           0.121430
# Vermont                   623989        852      47           0.136541
# Virginia                 8535519      13538     460           0.158608
# Washington               7614893      13583     764           0.178374
# West Virginia            1792147       1063      34           0.059314
# Wisconsin                5822434       6081     281           0.104441
# Wyoming                   578759        520       1           0.089847
#
#                       Deaths_per_100
# State
# Alabama                     0.004650
# Alaska                      0.000683
# Arizona                     0.003778
# Arkansas                    0.001690
# California                  0.004497
# Colorado                    0.012190
# Connecticut                 0.056405
# Delaware                    0.012837
# District of Columbia        0.026213
# Florida                     0.005066
# Georgia                     0.009230
# Hawaii                      0.001130
# Idaho                       0.003134
# Illinois                    0.015649
# Indiana                     0.012537
# Iowa                        0.004025
# Kansas                      0.004325
# Kentucky                    0.004768
# Louisiana                   0.036504
# Maine                       0.003794
# Maryland                    0.014192
# Massachusetts               0.043439
# Michigan                    0.033714
# Minnesota                   0.005071
# Mississippi                 0.007695
# Missouri                    0.005344
# Montana                     0.001310
# Nebraska                    0.001964
# Nevada                      0.006656
# New Hampshire               0.000221
# New Jersey                  0.068046
# New Mexico                  0.004721
# New York                    0.116513
# North Carolina              0.003242
# North Dakota                0.002493
# Ohio                        0.006442
# Oklahoma                    0.004979
# Oregon                      0.002181
# Pennsylvania                0.014732
# Rhode Island                0.000000
# South Carolina              0.003438
# South Dakota                0.001243
# Tennessee                   0.002650
# Texas                       0.002297
# Utah                        0.001123
# Vermont                     0.007532
# Virginia                    0.005389
# Washington                  0.010033
# West Virginia               0.001897
# Wisconsin                   0.004826
# Wyoming                     0.000173

# %%
# Now our data prep is done and we can start analyzing.

# The latest nationwide totals
cases_by_state[["Confirmed", "Deaths"]].sum()
# Out:
# Confirmed    978151
# Deaths        55616
# dtype: int64

# %%
# Today's nationwide totals, computed from the county-level data
cases_by_county[["Confirmed", "Deaths"]].sum()
# Out:
# Confirmed    978151
# Deaths        55616
# dtype: int64

# %%
# Top 10 states by confirmed cases:
cases_by_state.sort_values("Confirmed", ascending=False).head(10)
# Out:
#                Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# New York         19453561     291994   22666           1.500980
# New Jersey        8882190     110370    6044           1.242599
# Massachusetts     6892503      55642    2994           0.807283
# Illinois         12671821      45545    1983           0.359420
# California       39512223      44966    1777           0.113803
# Pennsylvania     12801989      43558    1886           0.340244
# Michigan          9986857      37056    3367           0.371048
# Florida          21477737      32137    1088           0.149629
# Louisiana         4648794      27004    1697           0.580882
# Connecticut       3565287      25513    2011           0.715595
#
#                Deaths_per_100
# State
# New York             0.116513
# New Jersey           0.068046
# Massachusetts        0.043439
# Illinois             0.015649
# California           0.004497
# Pennsylvania         0.014732
# Michigan             0.033714
# Florida              0.005066
# Louisiana            0.036504
# Connecticut          0.056405

# %%
# Top 10 states by confirmed cases per 100 residents
cases_by_state.sort_values("Confirmed_per_100", ascending=False).head(10)
# Out:
#                       Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# New York                19453561     291994   22666           1.500980
# New Jersey               8882190     110370    6044           1.242599
# Massachusetts            6892503      55642    2994           0.807283
# Connecticut              3565287      25513    2011           0.715595
# Rhode Island             1059361       6548       0           0.618108
# Louisiana                4648794      27004    1697           0.580882
# District of Columbia      705749       3892     185           0.551471
# Delaware                  973764       4151     125           0.426284
# Michigan                 9986857      37056    3367           0.371048
# Illinois                12671821      45545    1983           0.359420
#
#                       Deaths_per_100
# State
# New York                    0.116513
# New Jersey                  0.068046
# Massachusetts               0.043439
# Connecticut                 0.056405
# Rhode Island                0.000000
# Louisiana                   0.036504
# District of Columbia        0.026213
# Delaware                    0.012837
# Michigan                    0.033714
# Illinois                    0.015649

# %%
# Top 10 states by deaths per 100 residents
cases_by_state.sort_values("Deaths_per_100", ascending=False).head(10)
# Out:
#                       Population  Confirmed  Deaths  Confirmed_per_100  \
# State
# New York                19453561     291994   22666           1.500980
# New Jersey               8882190     110370    6044           1.242599
# Connecticut              3565287      25513    2011           0.715595
# Massachusetts            6892503      55642    2994           0.807283
# Louisiana                4648794      27004    1697           0.580882
# Michigan                 9986857      37056    3367           0.371048
# District of Columbia      705749       3892     185           0.551471
# Illinois                12671821      45545    1983           0.359420
# Pennsylvania            12801989      43558    1886           0.340244
# Maryland                 6045680      19487     858           0.322329
#
#                       Deaths_per_100
# State
# New York                    0.116513
# New Jersey                  0.068046
# Connecticut                 0.056405
# Massachusetts               0.043439
# Louisiana                   0.036504
# Michigan                    0.033714
# District of Columbia        0.026213
# Illinois                    0.015649
# Pennsylvania                0.014732
# Maryland                    0.014192

# %%
# Top 20 counties by total confirmed cases.
cases_by_county.sort_values("Confirmed", ascending=False).head(20)
# Out:
#             Date          State        County  Population  Confirmed  Deaths  \
# FIPS
# 36047 2020-04-27       New York         Kings     2559903      49279    5378
# 36081 2020-04-27       New York        Queens     2253858      43388    4735
# 36059 2020-04-27       New York        Nassau     1356924      34865    1620
# 36103 2020-04-27       New York       Suffolk     1476601      32470    1102
# 17031 2020-04-27       Illinois          Cook     5150233      31953    1347
# 36061 2020-04-27       New York      New York     1628706      31353    3421
# 36119 2020-04-27       New York   Westchester      967506      28007     962
# 36005 2020-04-27       New York         Bronx     1418207      27301    2979
# 6037  2020-04-27     California   Los Angeles    10039107      20423     944
# 26163 2020-04-27       Michigan         Wayne     1749343      15872    1622
# 34003 2020-04-27     New Jersey        Bergen      932202      15104     960
# 34017 2020-04-27     New Jersey        Hudson      672391      13925     673
# 34013 2020-04-27     New Jersey         Essex      798975      13047    1028
# 25017 2020-04-27  Massachusetts     Middlesex     1611699      12953     700
# 42101 2020-04-27   Pennsylvania  Philadelphia     1584064      12868     484
# 34039 2020-04-27     New Jersey         Union      556341      12011     583
# 25025 2020-04-27  Massachusetts       Suffolk      803907      11883     448
# 12086 2020-04-27        Florida    Miami-Dade     2716940      11570     302
# 36087 2020-04-27       New York      Rockland      325789      11366     481
# 34031 2020-04-27     New Jersey       Passaic      501826      11349     438
#
#        Recovered  Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier  \
# FIPS
# 36047          0              False           False              False
# 36081          0              False           False              False
# 36059          0              False           False              False
# 36103          0              False           False              False
# 17031          0              False           False              False
# 36061          0              False           False              False
# 36119          0              False           False              False
# 36005          0              False           False              False
# 6037           0              False           False              False
# 26163          0              False           False              False
# 34003          0              False           False              False
# 34017          0              False           False              False
# 34013          0              False           False              False
# 25017          0              False           False              False
# 42101          0              False           False              False
# 34039          0              False           False              False
# 25025          0              False           False              False
# 12086          0              False           False              False
# 36087          0              False           False              False
# 34031          0              False           False              False
#
#        Confirmed_per_100  Deaths_per_100
# FIPS
# 36047           1.925034        0.210086
# 36081           1.925055        0.210084
# 36059           2.569414        0.119388
# 36103           2.198969        0.074631
# 17031           0.620419        0.026154
# 36061           1.925025        0.210044
# 36119           2.894762        0.099431
# 36005           1.925036        0.210054
# 6037            0.203434        0.009403
# 26163           0.907312        0.092721
# 34003           1.620250        0.102982
# 34017           2.070968        0.100091
# 34013           1.632967        0.128665
# 25017           0.803686        0.043432
# 42101           0.812341        0.030554
# 34039           2.158928        0.104792
# 25025           1.478156        0.055728
# 12086           0.425847        0.011115
# 36087           3.488761        0.147642
# 34031           2.261541        0.087281

# %%
# Top 20 counties by confirmed cases per 100 residents
cases_by_county.sort_values("Confirmed_per_100", ascending=False).head(20)
# Out:
#             Date       State       County  Population  Confirmed  Deaths  \
# FIPS
# 5079  2020-04-27    Arkansas      Lincoln       13024        754       0
# 47007 2020-04-27   Tennessee      Bledsoe       15064        588       0
# 36087 2020-04-27    New York     Rockland      325789      11366     481
# 39101 2020-04-27        Ohio       Marion       65093       2188       4
# 39129 2020-04-27        Ohio     Pickaway       58457       1698       5
# 36119 2020-04-27    New York  Westchester      967506      28007     962
# 18017 2020-04-27     Indiana         Cass       37689       1025       1
# 36059 2020-04-27    New York       Nassau     1356924      34865    1620
# 19115 2020-04-27        Iowa       Louisa       11035        267       2
# 13243 2020-04-27     Georgia     Randolph        6778        156      19
# 31043 2020-04-27    Nebraska       Dakota       20026        459       0
# 34031 2020-04-27  New Jersey      Passaic      501826      11349     438
# 36103 2020-04-27    New York      Suffolk     1476601      32470    1102
# 34039 2020-04-27  New Jersey        Union      556341      12011     583
# 36071 2020-04-27    New York       Orange      384940       8238     299
# 16013 2020-04-27       Idaho       Blaine       23021        492       5
# 34017 2020-04-27  New Jersey       Hudson      672391      13925     673
# 13099 2020-04-27     Georgia        Early       10190        202      15
# 13273 2020-04-27     Georgia      Terrell        8531        167      18
# 36081 2020-04-27    New York       Queens     2253858      43388    4735
#
#        Recovered  Confirmed_Outlier  Deaths_Outlier  Recovered_Outlier  \
# FIPS
# 5079           0              False           False              False
# 47007          0              False           False              False
# 36087          0              False           False              False
# 39101          0              False           False              False
# 39129          0              False           False              False
# 36119          0              False           False              False
# 18017          0              False           False              False
# 36059          0              False           False              False
# 19115          0              False           False              False
# 13243          0              False           False              False
# 31043          0              False           False              False
# 34031          0              False           False              False
# 36103          0              False           False              False
# 34039          0              False           False              False
# 36071          0              False           False              False
# 16013          0              False           False              False
# 34017          0              False           False              False
# 13099          0              False           False              False
# 13273          0              False           False              False
# 36081          0              False           False              False
#
#        Confirmed_per_100  Deaths_per_100
# FIPS
# 5079            5.789312        0.000000
# 47007           3.903346        0.000000
# 36087           3.488761        0.147642
# 39101           3.361345        0.006145
# 39129           2.904699        0.008553
# 36119           2.894762        0.099431
# 18017           2.719626        0.002653
# 36059           2.569414        0.119388
# 19115           2.419574        0.018124
# 13243           2.301564        0.280319
# 31043           2.292020        0.000000
# 34031           2.261541        0.087281
# 36103           2.198969        0.074631
# 34039           2.158928        0.104792
# 36071           2.140074        0.077674
# 16013           2.137179        0.021719
# 34017           2.070968        0.100091
# 13099           1.982336        0.147203
# 13273           1.957567        0.210995
# 36081           1.925055        0.210084

# %%
# Top 20 counties by *deaths* per 100 residents
cases_by_county.sort_values("Deaths_per_100", ascending=False).head(20)
# Out:
#             Date       State                County  Population  Confirmed  \
# FIPS
# 13243 2020-04-27     Georgia              Randolph        6778        156
# 13273 2020-04-27     Georgia               Terrell        8531        167
# 36047 2020-04-27    New York                 Kings     2559903      49279
# 36081 2020-04-27    New York                Queens     2253858      43388
# 36005 2020-04-27    New York                 Bronx     1418207      27301
# 36061 2020-04-27    New York              New York     1628706      31353
# 36085 2020-04-27    New York              Richmond      476143       9166
# 22095 2020-04-27   Louisiana  St. John the Baptist       42837        751
# 36087 2020-04-27    New York              Rockland      325789      11366
# 13099 2020-04-27     Georgia                 Early       10190        202
# 13095 2020-04-27     Georgia             Dougherty       87956       1480
# 34013 2020-04-27  New Jersey                 Essex      798975      13047
# 13205 2020-04-27     Georgia              Mitchell       21863        293
# 30101 2020-04-27     Montana                 Toole        4736         29
# 36059 2020-04-27    New York                Nassau     1356924      34865
# 40055 2020-04-27    Oklahoma                 Greer        5712         64
# 34039 2020-04-27  New Jersey                 Union      556341      12011
# 22071 2020-04-27   Louisiana               Orleans      390144       6365
# 34003 2020-04-27  New Jersey                Bergen      932202      15104
# 18031 2020-04-27     Indiana               Decatur       26559        194
#
#        Deaths  Recovered  Confirmed_Outlier  Deaths_Outlier  \
# FIPS
# 13243      19          0              False           False
# 13273      18          0              False           False
# 36047    5378          0              False           False
# 36081    4735          0              False           False
# 36005    2979          0              False           False
# 36061    3421          0              False           False
# 36085    1000          0              False           False
# 22095      64          0              False           False
# 36087     481          0              False           False
# 13099      15          0              False           False
# 13095     114          0              False           False
# 34013    1028          0              False           False
# 13205      28          0              False           False
# 30101       6          0              False           False
# 36059    1620          0              False           False
# 40055       6          0              False           False
# 34039     583          0              False           False
# 22071     406          0              False           False
# 34003     960          0              False           False
# 18031      27          0              False           False
#
#        Recovered_Outlier  Confirmed_per_100  Deaths_per_100
# FIPS
# 13243              False           2.301564        0.280319
# 13273              False           1.957567        0.210995
# 36047              False           1.925034        0.210086
# 36081              False           1.925055        0.210084
# 36005              False           1.925036        0.210054
# 36061              False           1.925025        0.210044
# 36085              False           1.925052        0.210021
# 22095              False           1.753157        0.149404
# 36087              False           3.488761        0.147642
# 13099              False           1.982336        0.147203
# 13095              False           1.682660        0.129610
# 34013              False           1.632967        0.128665
# 13205              False           1.340164        0.128070
# 30101              False           0.612331        0.126689
# 36059              False           2.569414        0.119388
# 40055              False           1.120448        0.105042
# 34039              False           2.158928        0.104792
# 22071              False           1.631449        0.104064
# 34003              False           1.620250        0.102982
# 18031              False           0.730449        0.101660
